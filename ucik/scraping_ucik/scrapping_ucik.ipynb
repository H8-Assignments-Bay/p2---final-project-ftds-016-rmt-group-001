# %%
import pandas as pd
from random import randint

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# /var/folders/37/zw9ym1bn7f31rcp5g2cvjr8m0000gn/T/ipykernel_3109/3871533204.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
from selenium.webdriver.common.by import By
from dateutil import parser

symbols = ['STAA', 'STTP', 'ROTI', 'LSIP', 'TLDN', 'SIMP', 'PALM']

from time import sleep

df = pd.DataFrame()

for symbol in symbols:
    driver.get(f"https://stockbit.com/symbol/{symbol}")
    
    # Handdle: IndexError: list index out of range
    while True:
        date_elements = driver.find_elements(by=By.XPATH, value="//div[@class='stream-date']")
        
        # Handle: IndexError: list index out of range
        if len(date_elements) != 0:
            break

    while True:
        # date_elements[-2] Handle: StaleElementReferenceException or ''
        # .text[:16] Handle: ParserError: Unknown string format: 14 Dec 22, 19:42 · Edited on 14 Dec 22, 21:29
        if parser.parse(date_elements[-2].text[:16]) >= parser.parse("1 Oct 22"):
            driver.execute_script("window.scrollBy(0,document.body.scrollHeight)", "")
            date_elements = driver.find_elements(by=By.XPATH, value="//div[@class='stream-date']")
        else:
            break
    
    # value='stream-text-single' Handle: prevent Repost to be included in the comment_elements    
    comment_elements = driver.find_elements(by=By.CLASS_NAME, value="stream-text-single")
    
    dates = list()
    comments = list()
    
    for index, (date_element, comment_element) in enumerate(zip(date_elements, comment_elements)):
        # print(date_element.text, comment_element.text, "\n")
        
        # Handle: StaleElementReferenceException or ''
        if index == len(date_elements) - 1:
            break
        
        dates.append(date_element.text)
        comments.append(comment_element.text)
        
    print(f'symbol {symbol} '
          f'date_elements {len(date_elements)} dates {len(dates)} '
          f'comment_elements {len(comment_elements)} comments {len(comments)} ')
    
    df_c = pd.DataFrame()
    df_c['date'] = dates
    df_c['comment'] = comments
    df_c['symbol'] = symbol
    
    df = pd.concat([df, df_c])
    
    sleep(randint(5,10))
# Out:
# symbol STAA date_elements 641 dates 640 comment_elements 641 comments 640
# symbol STTP date_elements 41 dates 40 comment_elements 41 comments 40
# symbol ROTI date_elements 80 dates 79 comment_elements 80 comments 79
# symbol LSIP date_elements 361 dates 360 comment_elements 361 comments 360
# symbol TLDN date_elements 41 dates 40 comment_elements 41 comments 40
# symbol SIMP date_elements 141 dates 140 comment_elements 141 comments 140
# symbol PALM date_elements 121 dates 120 comment_elements 121 comments 120

# %%
df
# Out:
#                                               date  \
# 0                                 16 Dec 22, 13:19
# 1                                 16 Dec 22, 11:21
# 2                                 16 Dec 22, 08:38
# 3                                 15 Dec 22, 08:17
# 4                                 14 Dec 22, 22:53
# ..                                             ...
# 115  28 Sep 22, 06:33 · Edited on 28 Sep 22, 07:52
# 116   27 Sep 22, 12:07 · Edited on 3 Oct 22, 17:36
# 117  27 Sep 22, 11:00 · Edited on 27 Sep 22, 11:53
# 118                               26 Sep 22, 07:45
# 119                               23 Sep 22, 19:03
#
#                                                comment symbol
# 0    $STAA selama masih ada potensi positif di haka...   STAA
# 1    $LSIP $BWPT $SSMS $STAA B35 apa kabar $BOSS ?g...   STAA
# 2    Harga kontrak Crude Palm Oil (CPO) di Bursa Ma...   STAA
# 3    $STAA membuka peluang membentuk tren naik sete...   STAA
# 4    JAKARTA, https://cutt.ly/H0xp1zp - Harga kontr...   STAA
# ..                                                 ...    ...
# 115  🎖 Pantauan Saham🎖\n28-09-22\n\n✅ $DOID\n✅ $OPM...   PALM
# 116           $GZCO aja😁😁😁\n$ELSA\n$MEDC\n$AKRA\n$PALM   PALM
# 117  $GZCO\n$ELSA\n$MEDC\n$PALM\n$AKRA\n\n\nKemarin...   PALM
# 118                                              $PALM   PALM
# 119  @charlescharles $PALM $MPMX saratoga grup maya...   PALM
#
# [1419 rows x 3 columns]

# %%
df.to_csv("STAA_PALM.csv", index=False)

# %% [markdown]
# # Labelling

# %%
import pandas as pd

# %%
data = pd.read_csv('STAA_PALM.csv')

# %%
data.head()
# Out:
#                date                                            comment symbol
# 0  16 Dec 22, 13:19  $STAA selama masih ada potensi positif di haka...   STAA
# 1  16 Dec 22, 11:21  $LSIP $BWPT $SSMS $STAA B35 apa kabar $BOSS ?g...   STAA
# 2  16 Dec 22, 08:38  Harga kontrak Crude Palm Oil (CPO) di Bursa Ma...   STAA
# 3  15 Dec 22, 08:17  $STAA membuka peluang membentuk tren naik sete...   STAA
# 4  14 Dec 22, 22:53  JAKARTA, https://cutt.ly/H0xp1zp - Harga kontr...   STAA

# %%
def get_comment(index):
    print(data['symbol'][index])
    print (data['comment'][index])

# %%
def set_label(index: int, label_1: int, label_2: int):
    data['label_1'][index] = label_1
    data['label_2'][index] = label_2

# %%
get_comment(650)
# Out:
# STTP
# @bamzat sekalian beli $STTP #maksa

# %%
set_label(650,2,0)

# %%
data
# Out:
#                                                date  \
# 0                                  16 Dec 22, 13:19
# 1                                  16 Dec 22, 11:21
# 2                                  16 Dec 22, 08:38
# 3                                  15 Dec 22, 08:17
# 4                                  14 Dec 22, 22:53
# ...                                             ...
# 1414  28 Sep 22, 06:33 · Edited on 28 Sep 22, 07:52
# 1415   27 Sep 22, 12:07 · Edited on 3 Oct 22, 17:36
# 1416  27 Sep 22, 11:00 · Edited on 27 Sep 22, 11:53
# 1417                               26 Sep 22, 07:45
# 1418                               23 Sep 22, 19:03
#
#                                                 comment symbol label_1 label_2
# 0     $STAA selama masih ada potensi positif di haka...   STAA       2       0
# 1     $LSIP $BWPT $SSMS $STAA B35 apa kabar $BOSS ?g...   STAA       0       1
# 2     Harga kontrak Crude Palm Oil (CPO) di Bursa Ma...   STAA       1       0
# 3     $STAA membuka peluang membentuk tren naik sete...   STAA       2       0
# 4     JAKARTA, https://cutt.ly/H0xp1zp - Harga kontr...   STAA       2       0
# ...                                                 ...    ...     ...     ...
# 1414  🎖 Pantauan Saham🎖\n28-09-22\n\n✅ $DOID\n✅ $OPM...   PALM       1       0
# 1415           $GZCO aja😁😁😁\n$ELSA\n$MEDC\n$AKRA\n$PALM   PALM       1       0
# 1416  $GZCO\n$ELSA\n$MEDC\n$PALM\n$AKRA\n\n\nKemarin...   PALM       1       0
# 1417                                              $PALM   PALM       1       0
# 1418  @charlescharles $PALM $MPMX saratoga grup maya...   PALM       1       0
#
# [1419 rows x 5 columns]

# %%
data.head(50)
# Out:
#                                            date  \
# 0                              16 Dec 22, 13:19
# 1                              16 Dec 22, 11:21
# 2                              16 Dec 22, 08:38
# 3                              15 Dec 22, 08:17
# 4                              14 Dec 22, 22:53
# 5                              14 Dec 22, 22:15
# 6                              13 Dec 22, 14:58
# 7                              13 Dec 22, 08:50
# 8                              12 Dec 22, 07:54
# 9                              10 Dec 22, 15:34
# 10                             10 Dec 22, 15:30
# 11                              9 Dec 22, 17:51
# 12  9 Dec 22, 08:13 · Edited on 9 Dec 22, 08:14
# 13                              9 Dec 22, 07:32
# 14                              8 Dec 22, 20:50
# 15                              8 Dec 22, 18:54
# 16                              8 Dec 22, 13:03
# 17                              8 Dec 22, 08:32
# 18                              8 Dec 22, 08:30
# 19                              8 Dec 22, 07:54
# 20                              7 Dec 22, 19:23
# 21                              7 Dec 22, 17:03
# 22                              7 Dec 22, 15:45
# 23                              7 Dec 22, 15:30
# 24                              7 Dec 22, 11:19
# 25                              7 Dec 22, 11:18
# 26                              7 Dec 22, 08:59
# 27                              6 Dec 22, 12:47
# 28                              6 Dec 22, 07:44
# 29                              5 Dec 22, 17:25
# 30  5 Dec 22, 11:07 · Edited on 5 Dec 22, 11:07
# 31                              5 Dec 22, 09:57
# 32                              4 Dec 22, 07:15
# 33                              3 Dec 22, 21:29
# 34                              3 Dec 22, 13:17
# 35                              3 Dec 22, 10:42
# 36                              2 Dec 22, 14:00
# 37                              2 Dec 22, 10:43
# 38                              2 Dec 22, 09:37
# 39                              2 Dec 22, 09:27
# 40                              2 Dec 22, 07:14
# 41                              1 Dec 22, 20:36
# 42                              1 Dec 22, 19:29
# 43                              1 Dec 22, 11:42
# 44                              1 Dec 22, 10:16
# 45                              1 Dec 22, 07:17
# 46                              1 Dec 22, 00:36
# 47                             30 Nov 22, 19:25
# 48                             30 Nov 22, 12:38
# 49                             30 Nov 22, 07:52
#
#                                               comment symbol label_1 label_2
# 0   $STAA selama masih ada potensi positif di haka...   STAA       2       0
# 1   $LSIP $BWPT $SSMS $STAA B35 apa kabar $BOSS ?g...   STAA       0       1
# 2   Harga kontrak Crude Palm Oil (CPO) di Bursa Ma...   STAA       1       0
# 3   $STAA membuka peluang membentuk tren naik sete...   STAA       2       0
# 4   JAKARTA, https://cutt.ly/H0xp1zp - Harga kontr...   STAA       2       0
# 5   $STAA hari ini tertahan sama ma20.. peluang na...   STAA       2       0
# 6     $STAA break out MA 20,potensi lanjut besok, gan   STAA       2       0
# 7   Pungutan ekspor (PE) minyak mentah atau Crude ...   STAA       1       0
# 8   Dengan masih terjadinya perang Rusia-Ukraina,p...   STAA       1       0
# 9   @egar88simbolon iy cm klo di $STAA hrus sbar n...   STAA       2       0
# 10  @vivianshu kemaren dah ijo tuhb $STAA, udah mu...   STAA       2       0
# 11  $STAA ditutup. menguat saat IHSG terjun bebas ...   STAA       2       0
# 12  Katalis B30 sukses membuat harga CPO melejit, ...   STAA       2       0
# 13  Research & Development ICDX Girta Yoga mengata...   STAA       2       0
# 14  Lumayan cuan $CHEM lagi hari ini, untung pas r...   STAA       2       0
# 15  @egar88simbolon amin $STAA naik akhir tahun, k...   STAA       2       0
# 16  Regulasi yang diterapkan Kementerian Keuangan ...   STAA       0       0
# 17  Niat pemerintah menerapkan mandatori program c...   STAA       2       0
# 18          @mybintang sikat ni sesi 1 akwkawka $STAA   STAA       2       0
# 19  @wildanpart2 izin bertanya, kalo $CPO bagaiman...   STAA       0       0
# 20              hri ini $CPO naek, $STAA kpn naekny??   STAA       0       0
# 21  @manteps $STAA calon2 kayak $CHEM ga ya.. diem...   STAA       0       0
# 22                    @WardayaAmar sikat gannnn $STAA   STAA       2       0
# 23    Laporan Bulanan Registrasi Pemegang Efek [STAA]   STAA       0       0
# 24  @vivianshu cuan buat tahun baru ya gan akwkawk...   STAA       2       0
# 25                 @lingsirdewi sikat ka hehehe $STAA   STAA       2       0
# 26  $STAA Meski sempat menembus support di level 1...   STAA       2       0
# 27  MENGIDOLAKAN BOLEH, MENJADI FANATIK JANGAN\n\n...   STAA       0       1
# 28  Pergerakan harga CPO sepekan ini akan bergantu...   STAA       0       0
# 29  potensi peningkatan program mandatori biodiese...   STAA       2       0
# 30  @EkiSutiono $STAA sedang menguji kembali angka...   STAA       0       0
# 31  $STAA sideway sampe awal tahun $CPO\ntinggal t...   STAA       0       0
# 32                                              $STAA   STAA       0       1
# 33                    $STAA ngantri di 964 yah om.. 🙏   STAA       0       0
# 34                                              $STAA   STAA       0       1
# 35  @talithalatief $STAA senin bakal rebound donk....   STAA       2       0
# 36             $STAA naik dong jangan muter2 situ aja   STAA       0       0
# 37                       $STAA bid beton di 1000 $CPO   STAA       0       0
# 38  Ekonomi Diramal Suram, Tapi Harga CPO Kok Ogah...   STAA       2       0
# 39                       $STAA masih parkir yoo $IHSG   STAA       0       0
# 40  harga minyak sawit berjanga naik 0,98 persen k...   STAA       2       0
# 41  $STAA lowest sempat di 1.020 tetapi mengalami ...   STAA       2       0
# 42  @Anditajaya ah gitu, brhrap $STAA jg windress ...   STAA       1       0
# 43  Yang mau ikut akum ngekor bandar..\nbuy aja ci...   STAA       1       0
# 44  Koreksi yang terjadi di saham $STAA mulai terb...   STAA       2       0
# 45  Harga komoditas minyak sawit mentah (CPO) naik...   STAA       2       0
# 46  $STAA\nSecara valuasi masih tergolong murah. m...   STAA       0       0
# 47  @Karunasankaraa $STAA $LSIP $MGRO $ANJT borong...   STAA       0       0
# 48  @Karunasankaraa kyknya $STAA sm $MGRO menarik ...   STAA       0       0
# 49  Harga kontrak Crude Palm Oil (CPO)🌴 di Bursa M...   STAA       2       0

# %% [markdown]
# labeling  STAA sampe 130 berarti ada 131

# %%
data.iloc[:131].to_csv("STAA_label.csv", index=False)

# %% [markdown]
# labeling STTP 640 - 664

# %%
data.iloc[640:665].to_csv("STTP_label.csv", index=False)
